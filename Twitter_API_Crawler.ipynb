# %% [markdown]
# # Twitter API Crawler
#
# Ryan Kruse and Tharindu Lokukatagoda

# %% [markdown]
# ### Import Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import pandas as pd
# Out:
# Collecting apyori
#   Downloading https://files.pythonhosted.org/packages/5e/62/5ffde5c473ea4b033490617ec5caa80d59804875ad3c3c57c0976533a21a/apyori-1.1.2.tar.gz
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-cp36-none-any.whl size=5975 sha256=f66180706ebbf9923092e5ed61e05804cfe3e95ea2625056072623097c44fed0
#   Stored in directory: /root/.cache/pip/wheels/5d/92/bb/474bbadbc8c0062b9eb168f69982a0443263f8ab1711a8cad0
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %% [markdown]
# Mount Google Drive so we can save resulting data as CSV

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Twitter Authorization
#
# Set up Twitter authorization and check that it works.

# %%
#imporitng tweepy lib
import tweepy

#setting up twitter credentials and accessing API
auth = tweepy.OAuthHandler('***************','*****************')
auth.set_access_token('*****************','*************')
api = tweepy.API(auth)

#get twitter followers count of the current handle 
follower_count = api.get_user('realDonaldTrump').followers_count
print('Number of followers: ',follower_count)

print()
#declaring variable screen_name to current handle
screen_name = 'realDonaldTrump'
# Out:
# Number of followers:  87390609

# %% [markdown]
# ### Define Target Followers Function
#
# Define our API crawler function to get the followers of a given account.

# %%
def getTargetFollowers(screen_name, n=100, m=150):
  target_followers = list()
  n = m
  f = tweepy.Cursor(api.followers, screen_name).items(n)
  for fol in f:
    if not fol.protected:
      target_followers.append(fol.screen_name)
    if len(target_followers) == n:
      break
  print(len(target_followers))
  dff = pd.DataFrame(columns=target_followers)
  print(dff.shape)
  return(dff)

# %% [markdown]
# ### Crawl API for Target Followers
#
# Each column is an account that follows our target account.

# %%
biden_df = getTargetFollowers('JoeBiden')
biden_df.head()
# Out:
# 131
# (0, 131)
# Empty DataFrame
# Columns: [Cris98101, Myayay_LoveMaze, prosecco_nbooks, Sundhar_twitzz, hshzz3_, NSVomhof, loveforarianab, hmsgqueens, AgunAlif, W65Doug, logan_meece, rafaeladavantel, discostck, mrcrowley89x, R6Ismael_, jordan8515, hwkfsh, letti093, xcvijp, Francis82122212, ranguangran47, bokar_bokoum, fabiopaleixo, julieannelecote, Ryan85502394, Holden80987844, MusicBuildz, cate8b_, josshdz00, ChrisXD_XD, LaylaRoyalhigh, makhaaya, haiderali6665, SamwichMitchell, inmavargas07, lustlovrs, Muhamma71840711, v5MXqUkRUlkxeUY, emmikealoha, billybobby_q, LamarchePhilipe, Luis69904736, FeliciaRMartin1, TarotWhw, lovelyfernanda1, rb200020, MustafaKrcl, EdisonBedoya21, TayfunOez, carandcan, AjsMarcin, sunibra, MikeDuromolaMD, Alayna_Step1126, Balamur95646899, _lil_africa, QadirDarwish, ayanle_nor, hmd_hkm, pruitt_zoey, tokeyser, PedroJenner_, Montra_01, MdKawsa98748907, Saskia77422619, alexsearcy, SanankaOle, Juliana00527805, nomis_9, Bertho96602841, Itzael79376410, AlliedMOT, L0CALR4T, izzlars, supbruv33, JackieLujan02, JeanSeb61665545, KillerQueen_074, obada_jaradat, Johnadedeji20, foldedstxrs, NYCFROT1, BadameEtienne1, hendrrn, killmyniall, sarcasticdemon3, yuhbitchadoreme, onurintheskywit, venkad22529929, 101Hoodbrat, CraftyDiem, Georgin91751001, 1404Stj, bowhogdid, MaryFra98932676, shuggaray2003, reveluvchuu, zak_risha, WILBURWLUV, joexkenshin, ...]
# Index: []
#
# [0 rows x 131 columns]

# %%
# rs = list(dff.index)
# for r in rs:
#   dff = dff.drop(r)
# dff
# Out:
# Empty DataFrame
# Columns: [MD09166004, yoni45275079, rotrjustice, Leonard24074456, SandraK04235974, garbhanmccl, BiancvL, 1_jollyb0i, clairefawx, mdiyinsiz, _grace_garcia, bruh7774, mehelsizz, feelsooo1, giladbauman1, kaleb85897026, Mette27698593, ajani_sheppard, hX3HiXY3Btg3yBV, eSOgZkXBPl78bEo, complex_turkey, AmbreuilM, Emreulusy, emile_jac21, DemonFromHell19, barbara51821507, fionaamurphy, shanhao1993, angeldust______, Taulant49181975, hugoruedaparis, YesMeLion_, quirquinchoamot, yousefjousef1, Utzania1, anskaterina, danavaz27387007, Lily14691154, SambarRice1, ErinClaire88, DEYOUNG70407820, wild_wooly, sngarrett16, bonjinsalaryman, GaalBryan, HorMohLara2, BizzlexB, rosatbv, rauf_john, Ahmet78059052, Sarah69199324, _osmargoncaltta, Pyrex59106781, Dawn03023686, Candice99024042, RyanWil48928769, Bakingfaker1, EObabhu, DoUevenLiftBrah, top5tomo1, IRStudent5, tsu7001, PeterScherr2, qaweemk04, bsugiart11, VallYahya, Innocentag3, Alfredo84946580, Ayumi20269390, constabletljv2, birdonpeak, Hz98ZKxbITkvVmo, wooxx_01, SandyLo02815975, GAuror26, JackThatch, EmmanuelAkiapo, MaherKammoun5, Jan75095900, MissHail, JamesGoodyear16, AdeboyeAdetoro, MarcGaddis, AmyReiter13, whatwasthatabo1, Ebuka39197654, He95Nic, MarkRichway, AssouanTehua, sk_tale, ghostgames05, TerryCa31145272, Dsouzafamily4f1, PreslynNemar, _aedmond, hotsong81, hamezlucas, MusolRidwan, ChristineHotch6, CoreyDerfuss]
# Index: []
#
# [0 rows x 100 columns]

# %% [markdown]
# Optionally, write to CSV to save and read back in later.

# %%
# dff=pd.read_csv("/content/gdrive/My Drive/twitter_arl.csv", index_col='Unnamed: 0')
# dff.head(3)
# Out:
#                  Ribs23154805  fabozo1  ...  Bah7rain313  marandaneel
# DanielRiolo                 1        0  ...            0            0
# realDonaldTrump             1        1  ...            0            0
# CNEWS                       1        0  ...            0            0
#
# [3 rows x 97 columns]

# %% [markdown]
# ### Define Followers Functions
#
# These functions help to get the data we want: other accounts followed by Biden and Trump's Twitter followers.

# %%
def getFollowing(name, n):
  f = tweepy.Cursor(api.friends, name).items(n)
  following = list()
  for fol in f:
    following.append(fol.screen_name)
  print(len(following))
  return(following)

def getFollowingCount(name):
  c = api.get_user(name).friends_count
  return(c)

# %%
dff = biden_df.copy()

# %%
dff = pd.read_csv("/content/gdrive/My Drive/twitter_arl_biden.csv").set_index('Unnamed: 0')
print(dff.index)
print(dff.shape)
dff.head()
# Out:
# Index(['SenKamalaHarris', 'PeteButtigieg', 'KamalaHarris', 'JoeBiden',
#        'NCT_OFFICIAL_JP', 'NCTsmtown_DREAM', 'NCTsmtown_127', 'NCTsmtown',
#        'adamclanton', 'culturemap',
#        ...
#        'Beyonce', 'takerusegawa', 'akanesora9', 'Iovergrande', 'imaginse',
#        'kokorumi1213', 'nicolel56978258', 'ArianaWorldHQ', 'vallauris_2014',
#        'arianatorM2'],
#       dtype='object', name='Unnamed: 0', length=7114)
# (7114, 131)
#                  Cris98101  Myayay_LoveMaze  ...  ashpremium  NCordier62
# Unnamed: 0                                   ...
# SenKamalaHarris          1                0  ...           0           0
# PeteButtigieg            1                0  ...           0           0
# KamalaHarris             1                0  ...           0           0
# JoeBiden                 1                1  ...           0           0
# NCT_OFFICIAL_JP          1                0  ...           0           0
#
# [5 rows x 131 columns]

# %%
# time.sleep(60*15)
n = 100
count = 0
print(len(dff.sum()[dff.sum()==0]))
for col in dff.sum()[dff.sum()==0].index:
  print("Columns left:", len(dff.sum()[dff.sum()==0]))
  count += 1
  c = getFollowingCount(col)
  if c > n:
    c = n
  count += c
  print("Counts:")
  print(c)
  print(count)
  print("\n")
  if count < 204:
    following = getFollowing(col, n)
    for f in following:
      if f in dff.index:
        print("in")
        dff.loc[f, col] = 1
      else:
        dff.loc[f] = 0
        dff.loc[f, col] = 1
  else:
    print(dff)
    print("Sleeping for 15 minutes")
    time.sleep(15*60)
    count = c
    following = getFollowing(col, n)
    for f in following:
      if f in dff.index:
        print("in")
        dff.loc[f, col] = 1
      else:
        dff.loc[f] = 0
        dff.loc[f, col] = 1
  dff.to_csv("/content/gdrive/My Drive/twitter_arl_biden.csv")
dff
# Out:
# 10
# Columns left: 10
# Counts:
# 0
# 1
#
#
# 0
# Columns left: 10
# Counts:
# 0
# 2
#
#
# 0
# Columns left: 10
# Counts:
# 0
# 3
#
#
# 0
# Columns left: 10
# Counts:
# 0
# 4
#
#
# 0
# Columns left: 10
# Counts:
# 52
# 57
#
#
# 52
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Columns left: 9
# Counts:
# 100
# 158
#
#
# 100
# in
# in
# Columns left: 8
# Counts:
# 100
# 259
#
#
#                  Cris98101  Myayay_LoveMaze  ...  ashpremium  NCordier62
# Unnamed: 0                                   ...
# SenKamalaHarris          1                0  ...           0           0
# PeteButtigieg            1                0  ...           0           0
# KamalaHarris             1                0  ...           0           0
# JoeBiden                 1                1  ...           0           0
# NCT_OFFICIAL_JP          1                0  ...           0           0
# ...                    ...              ...  ...         ...         ...
# BanderitaX               0                0  ...           0           0
# 365scoresarabic          0                0  ...           0           0
# Betkoen90                0                0  ...           0           0
# aboazaz05                0                0  ...           0           0
# Abdualrahman_kf          0                0  ...           0           0
#
# [8009 rows x 130 columns]
# Sleeping for 15 minutes
# 100
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Columns left: 7
# Counts:
# 49
# 150
#
#
# 49
# in
# in
# in
# Columns left: 6
# Counts:
# 8
# 159
#
#
# 8
# in
# in
# in
# in
# in
# in
# in
# Columns left: 5
# Counts:
# 100
# 260
#
#
#                  Cris98101  Myayay_LoveMaze  ...  ashpremium  NCordier62
# Unnamed: 0                                   ...
# SenKamalaHarris          1                0  ...           0           0
# PeteButtigieg            1                0  ...           0           0
# KamalaHarris             1                0  ...           1           0
# JoeBiden                 1                1  ...           1           0
# NCT_OFFICIAL_JP          1                0  ...           0           0
# ...                    ...              ...  ...         ...         ...
# niinisto                 0                0  ...           0           0
# SarasvuoJari             0                0  ...           0           0
# TuomasEnbuske            0                0  ...           0           0
# hsfi                     0                0  ...           0           0
# CBSNews                  0                0  ...           1           0
#
# [8144 rows x 130 columns]
# Sleeping for 15 minutes
# 100
# in
# in
# in
# in
# in
#                  Cris98101  Myayay_LoveMaze  ...  ashpremium  NCordier62
# Unnamed: 0                                   ...
# SenKamalaHarris          1                0  ...           0           0
# PeteButtigieg            1                0  ...           0           0
# KamalaHarris             1                0  ...           1           0
# JoeBiden                 1                1  ...           1           1
# NCT_OFFICIAL_JP          1                0  ...           0           0
# ...                    ...              ...  ...         ...         ...
# Vincent_TheVivi          0                0  ...           0           1
# LeGurky                  0                0  ...           0           1
# SirGibsy                 0                0  ...           0           1
# ZEventfr                 0                0  ...           0           1
# s_k_i_suspendu           0                0  ...           0           1
#
# [8239 rows x 130 columns]

# %%
dff
# Out:
#                 Cris98101 Myayay_LoveMaze  ... ashpremium NCordier62
# SenKamalaHarris         1               0  ...          0          0
# PeteButtigieg           1               0  ...          0          0
# KamalaHarris            1               0  ...          0          0
# JoeBiden                1               1  ...          0          0
# NCT_OFFICIAL_JP         1               0  ...          0          0
# ...                   ...             ...  ...        ...        ...
# VanerTokyo              0               1  ...          0          0
# kekekepopopo            0               1  ...          0          0
# takedasatetsu           0               1  ...          0          0
# IKIHA_JI                0               1  ...          0          0
# CHANEL                  0               1  ...          0          0
#
# [197 rows x 131 columns]

# %%
dff.to_csv("/content/gdrive/My Drive/twitter_arl_biden.csv")

# %%
dff
# Out:
#                 Cris98101 Myayay_LoveMaze  ... ashpremium NCordier62
# SenKamalaHarris         1               0  ...          0          0
# PeteButtigieg           1               0  ...          0          0
# KamalaHarris            1               0  ...          0          0
# JoeBiden                1               1  ...          0          0
# NCT_OFFICIAL_JP         1               0  ...          0          0
# ...                   ...             ...  ...        ...        ...
# AlbertsStuff            0               0  ...          0          0
# rhupdatelog             0               0  ...          0          0
# reddietheteddy          0               0  ...          0          0
# LeahAshe                0               0  ...          0          0
# nightbarbie             0               0  ...          0          0
#
# [2416 rows x 131 columns]

# %%
# time.sleep(60*15)
n = 100
count = 0
print(len(dff.sum()[dff.sum()==0]))
for col in dff.sum()[dff.sum()==0].index:
  count += 1
  c = getFollowingCount(col)
  if c > n:
    c = n
  count += c
  print("Counts:")
  print(c)
  print(count)
  print("\n")
  if count < 200:
    following = getFollowing(col, n)
    for f in following:
      if f in dff.index:
        print("in")
        dff.loc[f, col] = 1
      else:
        dff.loc[f] = 0
        dff.loc[f, col] = 1
  else:
    print(dff)
    print("Sleeping for 15 minutes")
    time.sleep(15*60)
    count = c
    following = getFollowing(col, n)
    for f in following:
      if f in dff.index:
        print("in")
        dff.loc[f, col] = 1
      else:
        dff.loc[f] = 0
        dff.loc[f, col] = 1
  dff.to_csv("/content/gdrive/My Drive/twitter_arl_biden.csv")
dff

# %%
col
# Out:
# 'DandydeVk'

# %%
dff.sum()[dff.sum()==0].index
# Out:
# Index(['VSchouwenburg', 'Richard14113', 'BellDavy1', 'nancyjo23280541',
#        'AerospacNetwork', 'DandydeVk', 'michael_anema', 'Carol10909465',
#        'ZAKIROX12345671', 'Robin51379173', 'Madilyn96014814',
#        'Antonio05932177', 'GMom76', 'mounisabdou', 'RyanBel96071334',
#        'CarsonWhisler', 'Louie86825716', 'DavidBe42544015', 'mistamichael_',
#        'FliciP', 'kkyrafo', 'deidre_padgett', 'MohammadAliIsm5',
#        'KimberlyPocono', 'KaitlynMcNutt9', 'SaidiYusra', 'GlenGriggs8',
#        'CedricPlein', 'MaisieNoonan', 'pussyeggs1', 'NEO93691973',
#        'Salvato68760236', 'ennytao', 'JesseB168', 'julie05932405',
#        'SucyAishiteru', 'CoLbeZee', 'Whos_Jiana', 'BernadetteKoua8', 'jaxe29',
#        'clarisa_evelyn', 'dona_srt23', 'guga0121', 'ChristianSage15',
#        'Chipolino22', 'Selfieton', '23_steps', 'AminaWahbi6',
#        'Scottnunweiler1', 'ElhamAtashkar', 'NoaBarry', 'OutlawTyrants',
#        'AhmetUZ45055745', 'Tosin_Thompson', 'kiyunosuk', 'VictorS38864100',
#        'LaMbitMos', 'YolaCuevas2', 'hermit248', 'turpin_ronnie', 'mikerich_8',
#        'Edson30114703', 'khw88700706', 'fly2def', 'samusaniyowaiyo', 'jmz01',
#        'Shorty90649895', 'yayamanga4', 'Harald51465948', 'faamiab2k',
#        'Bah7rain313', 'marandaneel'],
#       dtype='object')

# %%
col
# Out:
# 'igorsrk'

# %%
dff
# Out:
#                  MD09166004  yoni45275079  ...  ChristineHotch6  CoreyDerfuss
# joe_commins1997           0             0  ...                0             0
# Ron_GriffithsJr           0             0  ...                0             0
# KSt2424                   0             0  ...                0             0
# MrsMendoza9               0             0  ...                0             0
# LeeSoldierOfCh1           0             0  ...                0             0
# ...                     ...           ...  ...              ...           ...
# salman_alodah             0             0  ...                0             0
# Dr_alqarnee               0             0  ...                0             0
# Alafasy                   0             0  ...                0             0
# MohamadAlarefe            0             0  ...                0             0
# shugairi                  0             0  ...                0             0
#
# [204 rows x 100 columns]

# %%
dff.to_csv("/content/gdrive/My Drive/twitter_arl.csv")

# %%
dff.head(3)
# Out:
#               MD09166004  yoni45275079  ...  ChristineHotch6  CoreyDerfuss
# GokturkMusic           1             0  ...                0             0
# Aklimdakises           1             0  ...                0             0
# unnamann               1             0  ...                0             0
#
# [3 rows x 100 columns]

# %%
count = 0
for col in dff.columns:
  if 1 not in dff[col].values:
    print(col)
    break
  count +=1
print(count)
# Out:
# Emreulusy
# 22

# %%
dff['MD09166004'].values
# Out:
# array([1, 1, 1, ..., 0, 0, 0])
